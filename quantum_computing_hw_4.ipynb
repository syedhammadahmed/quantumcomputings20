# %% [markdown]
# <a href="https://colab.research.google.com/github/syedhammadahmed/quantumcomputings20/blob/master/quantum_computing_hw_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## HW 3

# %% [markdown]
# ### Problem 1

# %% [markdown]
# **Fourier matrix**

# %% [markdown]
# Let $\omega=\mathrm{exp}(2\pi i/N)$ be the $N$th root of unity.  The Fourier matrix of size $N$ is the matrix $F_N=(q_{k,\ell})\in\mathbb{C}^{N\times N}$ whose entries are given by
# $$q_{k,\ell}=\frac{1}{\sqrt{N}} \omega^{k \cdot \ell}$$ for $k, \ell \in \{0,\ldots,N-1\}$.

# %% [markdown]
# Using numpy, implement the function ```get_fourier_matrix``` that creates the Fourier matrix of size $N$.
#
# Compute the eigenvalues of eigenvectors of the Fourier matrix.
#
# To check that your code is correct, you should verify the following properties:
#
# - the Fourier matrix is unitary
# - the fourth power of $F_N^4$ is equal to the identity matrix
# - its eigenvalues are $1, i, -1, -i$ (the multiplicities of these eigenvalues are given on the wikipedia page [discrete fourier transform](https://en.wikipedia.org/wiki/Discrete_Fourier_transform) in section *eigenvalues and eigenvectors*)

# %% [markdown]
# **Cyclic shift matrix**

# %% [markdown]
# The cyclic shift matrix is the matrix $P_N=(p_{k,\ell}\in\mathbb{C}^{N\times N}$ whose entries are given by
#
# $$ p_{k,\ell} = 1 \mbox{ if } \ell = k + 1 \pmod{N} $$
#
# $$ p_{k,\ell} = 0 \mbox{ if } \ell \neq k + 1 \pmod{N} $$

# %% [markdown]
# Using numpy, implement the function ```get_cyclic_shift_matrix``` that create the cyclic shift matrix of size $N$.
#
# Compute the eigenvalues of $P_N$.
#
# To show that your code is correct, you should verify the following properties:
#
# - the cyclic shift matrix is unitary
# - the $N$th power of the cyclic shift matrix is the identity matrix
# - the eigenvalues of the cyclic shift matrix are $N$th roots of unity
# - the cyclic shift matrix is diagonalized by the Fourier matrix, that is, $F_N^\dagger P_N F_N$ is diagonal.

# %%
import math
import cmath 
import numpy as np
import numpy.linalg as NPLA

# author: Syed Hammad Ahmed (5068474)

# to print values to this significant figures
roundTo = 4

#verbose mode ON or OFF
verbose = 0


# returns the n-th root of unity power k*l (Fourier matrix element [k][l])
def getNthRootMatrixValue(k, l, n):
  real = math.cos(2 * (k * l) * math.pi * 1.0/n)
  im = math.sin(2 * (k * l) * math.pi * 1.0/n)
  return (1.0/math.sqrt(n))*complex(real, im)

# returns fourier matrix where n is the argument
# n is the order of the matrix
def get_fourier_matrix(n):
  fourierMatrix = np.zeros((n,n), dtype=complex)
  for k in range(0, n):
    for l in range(0, n): 
      fourierMatrix[k][l] = getNthRootMatrixValue(k, l, n)
  return fourierMatrix

# returns the eigen values of a matrix
def getEigenValNVec(matrix):
  return NPLA.eigvals(matrix)

# returns the dagger (complex conjugate) of a matrix
def getDagger(matrix):
  return np.conj(matrix)

# returns the inverse of a matrix
def getInverse(matrix):
  return NPLA.inv(matrix)
  
# returns matrix^k
def getMatrixPowerK(matrix, k):
  return NPLA.matrix_power(matrix, k)

# returns identity matrix of order k
def identityK(k):
  return np.eye(k, dtype=complex)

# returns True if a matrix is unitary, False otherwise
def verifyUnitary(matrix):
  isUnitary = False
  matrixDagger = getDagger(matrix)
  matrixInverse = getInverse(matrix)
  if verbose:
    print("Dagger (Complex Conjugate):")
    print(np.round(matrixDagger, roundTo))
    print("Inverse:")
    print(np.round(matrixInverse, roundTo))
  # rounded to set same precision for both matrices
  if np.array_equal(np.round(matrixDagger, roundTo), np.round(matrixInverse, roundTo)):
    isUnitary = True
  return isUnitary  

# verifies if the k-th power of a matrix is equal to the identity matrix
def verifyKthPowerIdentity(matrix, k):
  isKthPowerIdentity = False
  matrixPowerK = getMatrixPowerK(matrix, k) 
  n = np.size(matrix, 0)
  identity = identityK(n)
  if verbose:
    print("matrix Power {}: ".format(k))
    print(np.round(matrixPowerK, roundTo))
    print("Identity:")
    print(identity)
  # rounded to set same precision for both matrices  
  if np.array_equal(np.round(matrixPowerK, roundTo), np.round(identity, roundTo)):
    isKthPowerIdentity = True
  return isKthPowerIdentity  

# verifies if eigenvalues of a matrix are 1, i, −1, −i
def verifyEigenValuesUnit(eigenValues):
  isEigenValuesUnit = False
  n = np.size(eigenValues)
  ones = np.ones(n)
  eigenValuesPower4 = np.power(eigenValues, 4)
  if verbose:
    print("eigenValues:", eigenValues)
    # print("eigenValues^4:", eigenValuesPower4)
    # print("Each eigen values power 4 == 1. Hence, 4-th roots of unity!")
  if np.array_equal(eigenValuesPower4, ones):
    isEigenValuesUnit = True
  return isEigenValuesUnit

# verifies if eigenvalues of a matrix are n-th roots of unity
def verifyEigenValuesNthRootsOfUnity(eigenValues, n):
  isEigenValuesNthRootsOfUnity = False
  n = np.size(eigenValues)
  ones = np.ones(n, dtype=complex)
  eigenValuesPowerN = np.power(eigenValues, n)
  eigenValuesPowerN = np.round(eigenValuesPowerN, roundTo-1)
  if verbose:
    print("eigenValues:", eigenValues)
    print("eigenValues^n:", eigenValuesPowerN)
  if np.array_equal(eigenValuesPowerN, np.round(ones, roundTo)):
    isEigenValuesNthRootsOfUnity = True
    print("Each (eigen-value power n) == 1. Hence, n-th roots of unity!")

  return isEigenValuesNthRootsOfUnity

 
# returns cyclic shift matrix where n is the argument
# n is the order of the matrix
# p[k,ℓ] = 1 if ℓ=k+1(modN) 
# p[k,ℓ] = 0 if ℓ≠k+1(modN)
def get_cyclic_shift_matrix(n):
  cyclicShiftMatrix = np.zeros((n,n), dtype=complex)
  for k in range(0, n):
    for l in range(0, n): 
      cyclicShiftMatrix[k][l] = int(l == ((k + 1) % n))
  return cyclicShiftMatrix

def roundIt(matrix):
  return np.round(matrix, roundTo)

def isDiag(m):
  rows, cols = np.shape(m)
  for i in range(0, rows):
    for j in range(0, cols):
      if (i!=j) and (m[i][j] != complex(0, 0)):
        print ("{}, {}".format(i, j))
        return False
  return True
    
# the cyclic shift matrix is diagonalized by the Fourier matrix, that is,  F†NPNFN  is diagonal.
def verifyDiagonalizable(cyclicShiftMatrix, fourierMatrix):
  isDiagonalizable = False
  fourierMatrixDagger = getDagger(fourierMatrix)
  diagonalMatrix = np.matmul(np.matmul(roundIt(fourierMatrixDagger), roundIt(cyclicShiftMatrix)), roundIt(fourierMatrix))
  if verbose:  
    print(roundIt(diagonalMatrix))
  if isDiag(roundIt(diagonalMatrix)):
    isDiagonalizable = True
  return isDiagonalizable

#test driver code tests for values of n = 4 to 1
def main():
  i = 4
  while(i):
    print("n =",i)
    fourierMatrix = get_fourier_matrix(i)
    print("Fourier Matrix:")
    print(np.round(fourierMatrix, roundTo))

    isUnitary = verifyUnitary(fourierMatrix)
    print("Fourier matrix is unitary? i.e. Dagger == Inverse? : ", end =" ")
    if isUnitary:
      print("TRUE")
    else:
      print("FALSE")

    is4thPowerIdentity = verifyKthPowerIdentity(fourierMatrix, 4)
    print("fourierMatrix^4 == Identity? : ", end =" ")
    if is4thPowerIdentity:
      print("TRUE")
    else:
      print("FALSE")

    eigenValues = np.round(getEigenValNVec(fourierMatrix), roundTo)
    # isEigenValuesUnit = verifyEigenValuesUnit(eigenValues)
    isEigenValuesUnit = verifyEigenValuesUnit(eigenValues)
    print("Fourier Matrix eigen values lie on complex unit circle? : ", end =" ")
    if isEigenValuesUnit:
      print("TRUE")
    else:
      print("FALSE")

    # cyclic shift matrix
    print("Cyclic Shift Matrix:")
    cyclicShiftMatrix = get_cyclic_shift_matrix(i)
    print(cyclicShiftMatrix)
    
    eigenValues = np.round(getEigenValNVec(cyclicShiftMatrix), roundTo)
  # the cyclic shift matrix is unitary
    isUnitary = verifyUnitary(cyclicShiftMatrix)
    print("Cyclic Shift matrix is unitary? i.e. Dagger == Inverse? : ", end =" ")
    if isUnitary:
      print("TRUE")
    else:
      print("FALSE")

  # the N th power of the cyclic shift matrix is the identity matrix
    isNthPowerIdentity = verifyKthPowerIdentity(cyclicShiftMatrix, i)
    print("cyclicShiftMatrix^{} == Identity? : ".format(i), end =" ")
    if isNthPowerIdentity:
      print("TRUE")
    else:
      print("FALSE")

  # the eigenvalues of the cyclic shift matrix are N th roots of unity
    isEigenValuesUnit = verifyEigenValuesNthRootsOfUnity(eigenValues, i)
    print("Cyclic Shift matrix are Nth roots of unity? : ", end =" ")
    if isEigenValuesUnit:
      print("TRUE")
    else:
      print("FALSE")

  # the cyclic shift matrix is diagonalized by the Fourier matrix, that is,  F†NPNFN  is diagonal.
    isDiagonalizable = verifyDiagonalizable(cyclicShiftMatrix, fourierMatrix)
    print("Cyclic Shift matrix diagonalized by the Fourier matrix? : ", end =" ")
    if isDiagonalizable:
      print("TRUE")
    else:
      print("FALSE")


    i = i - 1
    print("\n"*2)


if __name__ == "__main__":
    main()
# Out:
# n = 4
# Fourier Matrix:
# [[ 0.5+0.j   0.5+0.j   0.5+0.j   0.5+0.j ]
#  [ 0.5+0.j   0. +0.5j -0.5+0.j  -0. -0.5j]
#  [ 0.5+0.j  -0.5+0.j   0.5-0.j  -0.5+0.j ]
#  [ 0.5+0.j  -0. -0.5j -0.5+0.j   0. +0.5j]]
# Fourier matrix is unitary? i.e. Dagger == Inverse? :  TRUE
# fourierMatrix^4 == Identity? :  TRUE
# Fourier Matrix eigen values lie on complex unit circle? :  TRUE
# Cyclic Shift Matrix:
# [[0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j]]
# Cyclic Shift matrix is unitary? i.e. Dagger == Inverse? :  FALSE
# cyclicShiftMatrix^4 == Identity? :  TRUE
# Each (eigen-value power n) == 1. Hence, n-th roots of unity!
# Cyclic Shift matrix are Nth roots of unity? :  TRUE
# [[ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+1.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  0.-1.j]]
# Cyclic Shift matrix diagonalized by the Fourier matrix? :  TRUE
#
#
#
# n = 3
# Fourier Matrix:
# [[ 0.5774+0.j   0.5774+0.j   0.5774+0.j ]
#  [ 0.5774+0.j  -0.2887+0.5j -0.2887-0.5j]
#  [ 0.5774+0.j  -0.2887-0.5j -0.2887+0.5j]]
# Fourier matrix is unitary? i.e. Dagger == Inverse? :  TRUE
# fourierMatrix^4 == Identity? :  TRUE
# Fourier Matrix eigen values lie on complex unit circle? :  TRUE
# Cyclic Shift Matrix:
# [[0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j]]
# Cyclic Shift matrix is unitary? i.e. Dagger == Inverse? :  FALSE
# cyclicShiftMatrix^3 == Identity? :  TRUE
# Each (eigen-value power n) == 1. Hence, n-th roots of unity!
# Cyclic Shift matrix are Nth roots of unity? :  TRUE
# [[ 1.0002+0.j     -0.    +0.j     -0.    +0.j    ]
#  [ 0.    +0.j     -0.5   +0.8661j -0.    +0.j    ]
#  [ 0.    +0.j     -0.    +0.j     -0.5   -0.8661j]]
# Cyclic Shift matrix diagonalized by the Fourier matrix? :  TRUE
#
#
#
# n = 2
# Fourier Matrix:
# [[ 0.7071+0.j  0.7071+0.j]
#  [ 0.7071+0.j -0.7071+0.j]]
# Fourier matrix is unitary? i.e. Dagger == Inverse? :  TRUE
# fourierMatrix^4 == Identity? :  TRUE
# Fourier Matrix eigen values lie on complex unit circle? :  TRUE
# Cyclic Shift Matrix:
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]
# Cyclic Shift matrix is unitary? i.e. Dagger == Inverse? :  TRUE
# cyclicShiftMatrix^2 == Identity? :  TRUE
# Each (eigen-value power n) == 1. Hence, n-th roots of unity!
# Cyclic Shift matrix are Nth roots of unity? :  TRUE
# [[ 1.+0.j  0.+0.j]
#  [-0.+0.j -1.+0.j]]
# Cyclic Shift matrix diagonalized by the Fourier matrix? :  TRUE
#
#
#
# n = 1
# Fourier Matrix:
# [[1.+0.j]]
# Fourier matrix is unitary? i.e. Dagger == Inverse? :  TRUE
# fourierMatrix^4 == Identity? :  TRUE
# Fourier Matrix eigen values lie on complex unit circle? :  TRUE
# Cyclic Shift Matrix:
# [[1.+0.j]]
# Cyclic Shift matrix is unitary? i.e. Dagger == Inverse? :  TRUE
# cyclicShiftMatrix^1 == Identity? :  TRUE
# Each (eigen-value power n) == 1. Hence, n-th roots of unity!
# Cyclic Shift matrix are Nth roots of unity? :  TRUE
# [[1.+0.j]]
# Cyclic Shift matrix diagonalized by the Fourier matrix? :  TRUE

# %% [markdown]
# ### Problem 2

# %% [markdown]
# Using Qiskit IBM Q Experience, implement the quantum phase estimation circuit with 3-bit precision.
#
# This quantum circuit is explained on pages 110-113 (Inverse Fourier transform for 3 qubits) of the lecture slides.
#
# Write a function that create the state
#
# $$
# \frac{1}{\sqrt{2}} ( |0\rangle + e^{2\pi i 2^2 \varphi} |1\rangle ) \otimes
# \frac{1}{\sqrt{2}} ( |0\rangle + e^{2\pi i 2^1 \varphi} |1\rangle ) \otimes
# \frac{1}{\sqrt{2}} ( |0\rangle + e^{2\pi i 2^0 \varphi} |1\rangle )
# $$
#
# for arbitrary $\varphi\in [0,1)$.
#
# (This is the state that we would obtain by
# - preparing the three control bits in the $|+\rangle$ state
# - applying the control power of $U^{2^2}, U^{2^1}, U^{2^0}$ gates
#
# assuming that the target qubit is in state $|\psi\rangle$ and $U|\psi\rangle=e^{2 \pi i \varphi} |\psi\rangle$.)
#
# You can preprare the initial state applying ```U1``` gates on qubits prepared $|+\rangle$. See [Qiskit U1 gate documentation](https://qiskit.org/documentation/stubs/qiskit.extensions.U1Gate.html).
#
# The controlled $R_k^\dagger$ gates occuring in the inverse Fourier transform circuit can be realized with the help of controlled ```U1``` gates.

# %%
# !pip install qiskit==0.16.2
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
# Loading your IBM Q account(s)
# provider = IBMQ.load_account()

# Enable your account on Qiskit, replace 'My_API_Token' with your newly generated token
qiskit.IBMQ.save_account('f6500d0c95014269ca779482456925bf5a3236c4da2e8b9717e7e72af1a9a80a1e6736a0b27512b5416b0c8c74e7372b855b6e6359742b7528a237b57b3f9458')
qiskit.IBMQ.load_account()
# # After loading credentials we query the backends
# qiskit.IBMQ.backends()


# Useful additional packages
import matplotlib.pyplot as plt
import math
import cmath
import numpy as np

# author: Syed Hammad Ahmed (5068474)

def getTheta(bitNo, phi):
    return 2*pi*2**(3-bitNo-1)*phi

def initStates(phi):
    thetas = np.zeros(3)
    for i in range(3):
        thetas[i] = getTheta(i, phi)
    return thetas  
        
# def main():
backend = BasicAer.get_backend('unitary_simulator')
n = 3
q = QuantumRegister(n)
c = ClassicalRegister(n)
phi = 0.875

qc = QuantumCircuit(q, c)

# initilize states
thetas = initStates(phi)
for i in range(3):
    qc.h(q[i])
    qc.u1(getTheta(i, phi), q[i])

# inverse QFT     
qc.h(q[0])
qc.cu1(-pi/2, q[0], q[1])
qc.h(q[1])
qc.cu1(-pi/4, q[0], q[2])
qc.cu1(-pi/2, q[1], q[2])
qc.h(q[2])
qc.barrier()
qc.measure(q, c)
qc.draw()

# if __name__ == "__main__":
#     main()
# Out:
# Collecting qiskit==0.16.2
#   Downloading https://files.pythonhosted.org/packages/31/03/9a823e07f7b15ff8f474f09e30b756eb861ed0251f77d225ebef3aa13094/qiskit-0.16.2.tar.gz
# Collecting qiskit-terra==0.12.0
#   Downloading https://files.pythonhosted.org/packages/30/6e/3aada46aa05013279b918002a6123d9cf5d4014d65cef90f7f5306969ccc/qiskit_terra-0.12.0-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 2.8MB/s
# Collecting qiskit-aer==0.4.1
#   Downloading https://files.pythonhosted.org/packages/8e/02/0869865f03d799d135a550426f4f22d344b2eb6f555b42ff028ec16c8ebd/qiskit_aer-0.4.1-cp36-cp36m-manylinux2010_x86_64.whl (23.0MB)
#      |████████████████████████████████| 23.0MB 1.7MB/s
# Collecting qiskit-ibmq-provider==0.5.0
#   Downloading https://files.pythonhosted.org/packages/18/4f/49911087def9ba45406f18d10cc64e4ee73d8921e8d3fa2e5bf2abee3b71/qiskit_ibmq_provider-0.5.0-py3-none-any.whl (140kB)
#      |████████████████████████████████| 143kB 49.7MB/s
# Collecting qiskit-ignis==0.2.0
#   Downloading https://files.pythonhosted.org/packages/78/f2/f4f89c65d2c13f473092f7e800519836611ddeeaab8d4591a70555b26a37/qiskit_ignis-0.2.0-py3-none-any.whl (100kB)
#      |████████████████████████████████| 102kB 12.8MB/s
# Collecting qiskit-aqua==0.6.5
#   Downloading https://files.pythonhosted.org/packages/25/2d/ef2b2672c544a85a799dccc0de3c8dab88bee1b92cc84c302e01808eecfb/qiskit_aqua-0.6.5-py3-none-any.whl (1.8MB)
#      |████████████████████████████████| 1.8MB 46.3MB/s
# Collecting marshmallow<4,>=3
#   Downloading https://files.pythonhosted.org/packages/d8/0b/bb43d7610e71d87e8537025841c248471dbf938c676d32b8f94c82148c04/marshmallow-3.5.1-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 7.0MB/s
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.6/dist-packages (from qiskit-terra==0.12.0->qiskit==0.16.2) (1.4.1)
# Collecting sympy>=1.3
#   Downloading https://files.pythonhosted.org/packages/ce/5b/acc12e3c0d0be685601fc2b2d20ed18dc0bf461380e763afc9d0a548deb0/sympy-1.5.1-py2.py3-none-any.whl (5.6MB)
#      |████████████████████████████████| 5.6MB 48.1MB/s
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.6/dist-packages (from qiskit-terra==0.12.0->qiskit==0.16.2) (5.4.8)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.6/dist-packages (from qiskit-terra==0.12.0->qiskit==0.16.2) (2.6.0)
# Requirement already satisfied: networkx>=2.2; python_version > "3.5" in /usr/local/lib/python3.6/dist-packages (from qiskit-terra==0.12.0->qiskit==0.16.2) (2.4)
# Collecting marshmallow-polyfield<6,>=5.7
#   Downloading https://files.pythonhosted.org/packages/0c/7e/ceb805d05cd03709b8de122b4ac1e736c4eb91d05281ad2a2bcb484accef/marshmallow-polyfield-5.9.tar.gz
# Collecting ply>=3.10
#   Downloading https://files.pythonhosted.org/packages/a3/58/35da89ee790598a0700ea49b2a66594140f44dec458c07e8e3d4979137fc/ply-3.11-py2.py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 7.4MB/s
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.6/dist-packages (from qiskit-terra==0.12.0->qiskit==0.16.2) (0.3.1.1)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.6/dist-packages (from qiskit-terra==0.12.0->qiskit==0.16.2) (1.18.3)
# Collecting pybind11>=2.4
#   Downloading https://files.pythonhosted.org/packages/89/e3/d576f6f02bc75bacbc3d42494e8f1d063c95617d86648dba243c2cb3963e/pybind11-2.5.0-py2.py3-none-any.whl (296kB)
#      |████████████████████████████████| 296kB 46.4MB/s
# Requirement already satisfied: cython>=0.27.1 in /usr/local/lib/python3.6/dist-packages (from qiskit-aer==0.4.1->qiskit==0.16.2) (0.29.16)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.6/dist-packages (from qiskit-ibmq-provider==0.5.0->qiskit==0.16.2) (2.21.0)
# Collecting nest-asyncio!=1.1.0,>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/fb/98/f4add7297a8d586fe7ac756707673d03d97b9ed7c171291bb43889dbfbc5/nest_asyncio-1.3.2-py3-none-any.whl
# Collecting requests-ntlm>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/03/4b/8b9a1afde8072c4d5710d9fa91433d504325821b038e00237dc8d6d833dc/requests_ntlm-1.1.0-py2.py3-none-any.whl
# Collecting websockets<8,>=7
#   Downloading https://files.pythonhosted.org/packages/43/71/8bfa882b9c502c36e5c9ef6732969533670d2b039cbf95a82ced8f762b80/websockets-7.0-cp36-cp36m-manylinux1_x86_64.whl (63kB)
#      |████████████████████████████████| 71kB 10.0MB/s
# Collecting arrow>=0.15.5
#   Downloading https://files.pythonhosted.org/packages/92/fa/f84896dede5decf284e6922134bf03fd26c90870bbf8015f4e8ee2a07bcc/arrow-0.15.5-py2.py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 7.4MB/s
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.6/dist-packages (from qiskit-ignis==0.2.0->qiskit==0.16.2) (46.1.3)
# Collecting pyscf; sys_platform == "linux" or (python_version < "3.8" and sys_platform != "win32")
#   Downloading https://files.pythonhosted.org/packages/7a/ea/8ebe88368935dcc9a1a309764846e0bf5d04352d44067741aab3626ceb7f/pyscf-1.7.1-cp36-cp36m-manylinux1_x86_64.whl (24.3MB)
#      |████████████████████████████████| 24.3MB 126kB/s
# Collecting quandl
#   Downloading https://files.pythonhosted.org/packages/07/ab/8cd479fba8a9b197a43a0d55dd534b066fb8e5a0a04b5c0384cbc5d663aa/Quandl-3.5.0-py2.py3-none-any.whl
# Collecting docplex
#   Downloading https://files.pythonhosted.org/packages/03/a8/5dc675dbe179a2bd4d1d40522f009b4517ad32890d55ae49449709128d0a/docplex-2.13.184.tar.gz (571kB)
#      |████████████████████████████████| 573kB 50.2MB/s
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from qiskit-aqua==0.6.5->qiskit==0.16.2) (0.22.2.post1)
# Requirement already satisfied: fastdtw in /usr/local/lib/python3.6/dist-packages (from qiskit-aqua==0.6.5->qiskit==0.16.2) (0.3.4)
# Collecting dlx
#   Downloading https://files.pythonhosted.org/packages/54/c0/b8fb5bb727e983b6f5251433ef941b48f38c65bb0bd6ec509e9185bcd406/dlx-1.0.4.tar.gz
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from qiskit-aqua==0.6.5->qiskit==0.16.2) (2.10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy>=1.3->qiskit-terra==0.12.0->qiskit==0.16.2) (1.1.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.2; python_version > "3.5"->qiskit-terra==0.12.0->qiskit==0.16.2) (4.4.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.5.0->qiskit==0.16.2) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.5.0->qiskit==0.16.2) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.5.0->qiskit==0.16.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19->qiskit-ibmq-provider==0.5.0->qiskit==0.16.2) (2020.4.5.1)
# Collecting cryptography>=1.3
#   Downloading https://files.pythonhosted.org/packages/3c/04/686efee2dcdd25aecf357992e7d9362f443eb182ecd623f882bc9f7a6bba/cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 41.3MB/s
# Collecting ntlm-auth>=1.0.2
#   Downloading https://files.pythonhosted.org/packages/50/09/5e397eb18685b14fd8b209e26cdb4fa6451c82c1bcc651fef05fa73e7b27/ntlm_auth-1.4.0-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from arrow>=0.15.5->qiskit-ibmq-provider==0.5.0->qiskit==0.16.2) (2.8.1)
# Requirement already satisfied: pandas>=0.14 in /usr/local/lib/python3.6/dist-packages (from quandl->qiskit-aqua==0.6.5->qiskit==0.16.2) (1.0.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from quandl->qiskit-aqua==0.6.5->qiskit==0.16.2) (1.12.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.6/dist-packages (from quandl->qiskit-aqua==0.6.5->qiskit==0.16.2) (8.2.0)
# Collecting inflection>=0.3.1
#   Downloading https://files.pythonhosted.org/packages/52/c1/36be286d85dbd76527fb613527222a795d7c071da195fa916e7bf3cb03cb/inflection-0.4.0-py2.py3-none-any.whl
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.6.5->qiskit==0.16.2) (0.14.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.5.0->qiskit==0.16.2) (1.14.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.14->quandl->qiskit-aqua==0.6.5->qiskit==0.16.2) (2018.9)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.5.0->qiskit==0.16.2) (2.20)
# Building wheels for collected packages: qiskit, marshmallow-polyfield, docplex, dlx
#   Building wheel for qiskit (setup.py) ... done
#   Created wheel for qiskit: filename=qiskit-0.16.2-cp36-none-any.whl size=2898 sha256=e786aa8babadce3d9372080e14bb4e43d033f22444df55f0ee65c8cc9a571e7e
#   Stored in directory: /root/.cache/pip/wheels/8d/eb/5a/ce0d4fa7714b1b698c55bfbe41179f3993ac6a67f992cbf82e
#   Building wheel for marshmallow-polyfield (setup.py) ... done
#   Created wheel for marshmallow-polyfield: filename=marshmallow_polyfield-5.9-cp36-none-any.whl size=8537 sha256=c9d21aa7973aab6090b60415081444b88932bca3ff32e249e0e4cf69ed3584bd
#   Stored in directory: /root/.cache/pip/wheels/69/27/3e/7472f75eab2db111aa387715fe009af15899459517fc1a1906
#   Building wheel for docplex (setup.py) ... done
#   Created wheel for docplex: filename=docplex-2.13.184-cp36-none-any.whl size=633100 sha256=3c0788652d6137ebcde617393d455ea68daded394d253e3f07a2da2a30ac35ee
#   Stored in directory: /root/.cache/pip/wheels/35/67/46/e9d3c1cb652addc314816a29396c1c427c2735e8f6c656aab3
#   Building wheel for dlx (setup.py) ... done
#   Created wheel for dlx: filename=dlx-1.0.4-cp36-none-any.whl size=5712 sha256=8c2cf80b5a97e5e4bb91fcc2a15848bf349a66e0210b94407af5e2345aa5e919
#   Stored in directory: /root/.cache/pip/wheels/bb/ba/15/fdd0deb104df3254912998150ba9245668db06b00af5912d1a
# Successfully built qiskit marshmallow-polyfield docplex dlx
# Installing collected packages: marshmallow, sympy, marshmallow-polyfield, ply, qiskit-terra, pybind11, qiskit-aer, nest-asyncio, cryptography, ntlm-auth, requests-ntlm, websockets, arrow, qiskit-ibmq-provider, qiskit-ignis, pyscf, inflection, quandl, docplex, dlx, qiskit-aqua, qiskit
#   Found existing installation: sympy 1.1.1
#     Uninstalling sympy-1.1.1:
#       Successfully uninstalled sympy-1.1.1
# Successfully installed arrow-0.15.5 cryptography-2.9.2 dlx-1.0.4 docplex-2.13.184 inflection-0.4.0 marshmallow-3.5.1 marshmallow-polyfield-5.9 nest-asyncio-1.3.2 ntlm-auth-1.4.0 ply-3.11 pybind11-2.5.0 pyscf-1.7.1 qiskit-0.16.2 qiskit-aer-0.4.1 qiskit-aqua-0.6.5 qiskit-ibmq-provider-0.5.0 qiskit-ignis-0.2.0 qiskit-terra-0.12.0 quandl-3.5.0 requests-ntlm-1.1.0 sympy-1.5.1 websockets-7.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-69309dd6ecc5> in <module>()
#       9
#      10 # Enable your account on Qiskit, replace 'My_API_Token' with your newly generated token
# ---> 11 qiskit.IBMQ.save_account('f6500d0c95014269ca779482456925bf5a3236c4da2e8b9717e7e72af1a9a80a1e6736a0b27512b5416b0c8c74e7372b855b6e6359742b7528a237b57b3f9458')
#      12 qiskit.IBMQ.load_account()
#      13 # # After loading credentials we query the backends
#
# NameError: name 'qiskit' is not defined

# %%
import qiskit
qiskit.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-1eb96b00e4b6> in <module>()
# ----> 1 import qiskit
#       2 qiskit.__version__
#
# ModuleNotFoundError: No module named 'qiskit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import time
from qiskit import ClassicalRegister, QuantumRegister
from qiskit import QuantumCircuit,  available_backends, execute, register, get_backend
from qiskit.tools.visualization import circuit_drawer
from qiskit.quantum_info import state_fidelity
from qiskit import BasicAer
Useful additional packages
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi

# author: Syed Hammad Ahmed (5068474)

APItoken = 'f6500d0c95014269ca779482456925bf5a3236c4da2e8b9717e7e72af1a9a80a1e6736a0b27512b5416b0c8c74e7372b855b6e6359742b7528a237b57b3f9458'

qx_config = {
    "APItoken": APItoken,
    "url":"https://quantumexperience.ng.bluemix.net/api"}


#test driver code
def main():
  backend = BasicAer.get_backend('unitary_simulator')
  n = 3
  q = QuantumRegister(n)
  c = ClassicalRegister(n)

  qc = QuantumCircuit(q, c)

  qc.h(q[0])
  qc.cu1(-pi/2, q[0], q[1])
  qc.h(q[1])
  qc.cu1(-pi/2, q[0], q[2])
  qc.cu1(-pi/2, q[1], q[2])
  qc.h(q[2])
  qc.measure(q, c)
  qc.draw()


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-95-52655b088341> in <module>()
# ----> 1 import qiskit
#       2 # import time
#       3 # from qiskit import ClassicalRegister, QuantumRegister
#       4 # from qiskit import QuantumCircuit,  available_backends, execute, register, get_backend
#       5 # from qiskit.tools.visualization import circuit_drawer
#
# /usr/local/lib/python3.6/dist-packages/qiskit/__init__.py in <module>()
#      45
#      46 # Please note these are global instances, not modules.
# ---> 47 from qiskit.providers.basicaer import BasicAer
#      48
#      49 # Try to import the Aer provider if installed.
#
# /usr/local/lib/python3.6/dist-packages/qiskit/providers/__init__.py in <module>()
#      52 import pkgutil
#      53
# ---> 54 from .basebackend import BaseBackend
#      55 from .baseprovider import BaseProvider
#      56 from .basejob import BaseJob
#
# /usr/local/lib/python3.6/dist-packages/qiskit/providers/basebackend.py in <module>()
#      22
#      23 from qiskit.version import VERSION as __version__
# ---> 24 from .models import BackendStatus
#      25
#      26
#
# /usr/local/lib/python3.6/dist-packages/qiskit/providers/models/__init__.py in <module>()
#      45 from .backendstatus import BackendStatus
#      46 from .jobstatus import JobStatus
# ---> 47 from .pulsedefaults import PulseDefaults, Command
#
# /usr/local/lib/python3.6/dist-packages/qiskit/providers/models/pulsedefaults.py in <module>()
#      21 from qiskit.validation import BaseModel, BaseSchema, bind_schema, fields
#      22 from qiskit.validation.base import ObjSchema
# ---> 23 from qiskit.qobj import PulseLibraryItemSchema, PulseQobjInstructionSchema, PulseLibraryItem
#      24 from qiskit.qobj.converters import QobjToInstructionConverter
#      25 from qiskit.pulse.instruction_schedule_map import InstructionScheduleMap
#
# ImportError: cannot import name 'PulseLibraryItemSchema'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import time
from qiskit import ClassicalRegister, QuantumRegister
from qiskit import QuantumCircuit,  available_backends, execute, register, get_backend
from qiskit.tools.visualization import circuit_drawer
from qiskit.quantum_info import state_fidelity
from qiskit import BasicAer
from qiskit import QuantumProgram

# Useful additional packages
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi

# author: Syed Hammad Ahmed (5068474)

backend = 'ibmqx5'

APItoken = 'f6500d0c95014269ca779482456925bf5a3236c4da2e8b9717e7e72af1a9a80a1e6736a0b27512b5416b0c8c74e7372b855b6e6359742b7528a237b57b3f9458'

qx_config = {
    "APItoken": APItoken,
    "url":"https://quantumexperience.ng.bluemix.net/api"}


#test driver code
def main():
  qp = QuantumProgram()

  backend = BasicAer.get_backend('unitary_simulator')
  n = 3
  q = QuantumRegister(n)
  c = ClassicalRegister(n)

  qc = QuantumCircuit(q, c)
  qc = qp.create_circuit('HelloWorldCircuit', [q],[c])

  qc.h(q[0])
  qc.cu3(0, 0, -pi/2, q[0], q[1])
  qc.h(q[1])
  qc.cu3(0, 0, -pi/2, q[0], q[2])
  qc.cu3(0, 0, -pi/2, q[1], q[2])
  qc.h(q[2])
  qc.measure(q, c)
  qc.draw()

  qp.set_api(token,url='https://quantumexperience.ng.bluemix.net/api')

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-56f53ce90392> in <module>()
#       1 import time
# ----> 2 from qiskit import ClassicalRegister, QuantumRegister
#       3 from qiskit import QuantumCircuit,  available_backends, execute, register, get_backend
#       4 from qiskit.tools.visualization import circuit_drawer
#       5 from qiskit.quantum_info import state_fidelity
#
# ModuleNotFoundError: No module named 'qiskit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
